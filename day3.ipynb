# %%
# indexing
lst = [1,2,3,4,5]

# %%
# reverse
lst[::-1]
# Out:
# [5, 4, 3, 2, 1]

# %%
# all immutable datatypes can be stored as keys in dictionary

# %%
lst[0]=40

# %%
lst
# Out:
# [40, 2, 3, 4, 5]

# %%
lst[0:2]=[1,2]
lst
# Out:
# [1, 2, 3, 4, 5]

# %%
# dl dict['roll']

# %%
lst
