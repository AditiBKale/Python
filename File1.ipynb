# %%
print("Hello World")
# Out:
# Hello World

# %%
a = int(20.3)
a
# Out:
# 20

# %%
a = str(20.3)
a
# Out:
# '20.3'

# %%
type(a)
# Out:
# int

# %%
a = 10.3

# %%
type(a)
# Out:
# float

# %%
type(a)
# Out:
# str
